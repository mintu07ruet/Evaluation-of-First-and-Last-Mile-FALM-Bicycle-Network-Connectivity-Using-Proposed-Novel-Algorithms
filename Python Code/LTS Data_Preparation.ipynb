# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import shape
import fiona
from shapely.ops import unary_union
import networkx as nx
import itertools
import osmnx as ox
import math
import momepy
import matplotlib.pyplot as plt
from shapely.geometry import Point
import io
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# C:\Users\mmmiah\AppData\Local\Temp\ipykernel_13980\2680479345.py:3: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# import SF Road_network
road_network=gpd.read_file('H:/mmmiah/Desktop/Bicycle Connectivity Project/SF Validation_data/Data From Jane/Data_Sept 13/Speed_aadt.json', driver="GeoJSON")
road_network.head()
# Out:
#    FID     cnn street st_type       from_st      to_st  speedlimit schoolzone  \
# 0    0       0                                                  15        YES
# 1    1  107000   01ST      ST     HOWARD ST  TEHAMA ST          25
# 2    2  101000   01ST      ST  STEVENSON ST  JESSIE ST          25
# 3    3  105000   01ST      ST      MINNA ST  NATOMA ST          25
# 4    4  106000   01ST      ST     NATOMA ST  HOWARD ST          25
#
#    schoolzo_2 status  ...    L_mile  OBJECTID  Join_Count  TARGET_FID  \
# 0           0         ...  0.110859         1           1           0
# 1           0         ...  0.042996         2           1           1
# 2           0         ...  0.033369         3           1           2
# 3           0         ...  0.035847         4           1           3
# 4           0         ...  0.041568         5           1           4
#
#     longitude   latitude  Field3     AADT  Shape_Length  \
# 0 -122.412205  37.755685    None    966.0      0.001610
# 1 -122.395765  37.788340    None  30809.0      0.000709
# 2 -122.398155  37.790235    None  35019.0      0.000550
# 3 -122.396585  37.789000    None  33893.0      0.000590
# 4 -122.396130  37.788625    None  36199.0      0.000685
#
#                                             geometry
# 0  LINESTRING (-122.41220 37.75583, -122.41205 37...
# 1  LINESTRING (-122.39603 37.78854, -122.39548 37...
# 2  LINESTRING (-122.39859 37.79057, -122.39816 37...
# 3  LINESTRING (-122.39703 37.78933, -122.39657 37...
# 4  LINESTRING (-122.39657 37.78896, -122.39603 37...
#
# [5 rows x 21 columns]

# %%
#road_network.crs

# %%
road_network1=road_network.drop(['schoolzone',
 'schoolzo_2',
 'status',
 'workorder',
 'OBJECTID',
 'Join_Count',
 'TARGET_FID',
 'longitude',
 'latitude','Field3','Shape_Length','AADT'],axis=1)
road_network1.head()
#road_network1 = road_network1.rename(columns={'AADBT': 'AADT'})
# Out:
#    FID     cnn street st_type       from_st      to_st  speedlimit    L_mile  \
# 0    0       0                                                  15  0.110859
# 1    1  107000   01ST      ST     HOWARD ST  TEHAMA ST          25  0.042996
# 2    2  101000   01ST      ST  STEVENSON ST  JESSIE ST          25  0.033369
# 3    3  105000   01ST      ST      MINNA ST  NATOMA ST          25  0.035847
# 4    4  106000   01ST      ST     NATOMA ST  HOWARD ST          25  0.041568
#
#                                             geometry
# 0  LINESTRING (-122.41220 37.75583, -122.41205 37...
# 1  LINESTRING (-122.39603 37.78854, -122.39548 37...
# 2  LINESTRING (-122.39859 37.79057, -122.39816 37...
# 3  LINESTRING (-122.39703 37.78933, -122.39657 37...
# 4  LINESTRING (-122.39657 37.78896, -122.39603 37...

# %%
road_network1['cnn'].nunique()
# Out:
# 15715

# %%
# Now read the road network with OSM functional class
func=gpd.read_file('H:/mmmiah/Desktop/Bicycle Connectivity Project/SF Validation_data/Data From Jane/Data_Sept 13/speed_aadt_fun.json', driver="GeoJSON")
func.head()
# Out:
#    FID     cnn street st_type       from_st      to_st  speedlimit schoolzone  \
# 0    0       0                                                  15        YES
# 1    1  107000   01ST      ST     HOWARD ST  TEHAMA ST          25
# 2    2  101000   01ST      ST  STEVENSON ST  JESSIE ST          25
# 3    3  105000   01ST      ST      MINNA ST  NATOMA ST          25
# 4    4  106000   01ST      ST     NATOMA ST  HOWARD ST          25
#
#    schoolzo_2 status  ... OBJECTID  Join_Count TARGET_FID   longitude  \
# 0           0         ...        1           1          0 -122.412183
# 1           0         ...        2           1          1 -122.395765
# 2           0         ...        3           1          2 -122.398155
# 3           0         ...        4           1          3 -122.396585
# 4           0         ...        5           1          4 -122.396585
#
#     latitude Field3     AADT  Shape_Length    Shape_Area  \
# 0  37.755410   None    971.0      0.003611  2.342982e-07
# 1  37.788340   None  30809.0      0.001808  9.820555e-08
# 2  37.790235   None  35019.0      0.001491  7.888605e-08
# 3  37.789000   None  33893.0      0.001572  8.385906e-08
# 4  37.789000   None  33893.0      0.001762  9.533942e-08
#
#                                             geometry
# 0  POLYGON ((-122.41213 37.75584, -122.41213 37.7...
# 1  POLYGON ((-122.39598 37.78857, -122.39599 37.7...
# 2  POLYGON ((-122.39854 37.79061, -122.39855 37.7...
# 3  POLYGON ((-122.39698 37.78937, -122.39699 37.7...
# 4  POLYGON ((-122.39652 37.78900, -122.39653 37.7...
#
# [5 rows x 49 columns]

# %%
func1=func.drop([ 'schoolzone',
 'schoolzo_2',
 'status',
 'workorder',
 'OBJECTID',
 'Join_Count',
 'TARGET_FID',
  'SPEED_LIMI', 'FT_BIKE_01','TF_BIKE_01', 'FT_CROSS_L',
 'TF_CROSS_L',
 'TWLTL_CROS',
 'FT_INT_STR',
 'TF_SEG_STR',
 'TF_INT_STR',
 'XWALK',
 'Length',
 'Shape_Le_2',
 'Shape_Ar_1','geometry'],axis=1)
func1.head()
#func1 = func1.rename(columns={'AADBT': 'AADT'})
# Out:
#    FID     cnn street st_type       from_st      to_st  speedlimit  ROAD_ID  \
# 0    0       0                                                  15   917046
# 1    1  107000   01ST      ST     HOWARD ST  TEHAMA ST          25   847691
# 2    2  101000   01ST      ST  STEVENSON ST  JESSIE ST          25   843778
# 3    3  105000   01ST      ST      MINNA ST  NATOMA ST          25   844076
# 4    4  106000   01ST      ST     NATOMA ST  HOWARD ST          25   839925
#
#                   OSMID FUNCTIONAL  ...  TF_LANES FT_PARK  TF_PARK  \
# 0  {27028861,398499277}   tertiary  ...         0       0        0
# 1            {91181770}  secondary  ...         0       0        0
# 2             {8919020}  secondary  ...         0       1        1
# 3           {175507524}  secondary  ...         0       0        0
# 4            {91181770}  secondary  ...         0       0        0
#
#    FT_SEG_STR   longitude   latitude Field3     AADT  Shape_Length  \
# 0           3 -122.412183  37.755410   None    971.0      0.003611
# 1           4 -122.395765  37.788340   None  30809.0      0.001808
# 2           4 -122.398155  37.790235   None  35019.0      0.001491
# 3           4 -122.396585  37.789000   None  33893.0      0.001572
# 4           4 -122.396585  37.789000   None  33893.0      0.001762
#
#      Shape_Area
# 0  2.342982e-07
# 1  9.820555e-08
# 2  7.888605e-08
# 3  8.385906e-08
# 4  9.533942e-08
#
# [5 rows x 28 columns]

# %%
road_network1.shape, func1.shape
# Out:
# ((16572, 10), (16572, 28))

# %%
# Now combine, aadt+speed+OSM functional class data together
lts_data=pd.merge(road_network1,func1, on=['cnn','FID'], how='inner')
lts_data = lts_data.rename(columns={'speedlimit_x': 'speedlimit'})
lts_data.shape
# Out:
# (16572, 35)

# %%
lts_data.head()
# Out:
#    FID     cnn street_x st_type_x     from_st_x    to_st_x  speedlimit  \
# 0    0       0                                                      15
# 1    1  107000     01ST        ST     HOWARD ST  TEHAMA ST          25
# 2    2  101000     01ST        ST  STEVENSON ST  JESSIE ST          25
# 3    3  105000     01ST        ST      MINNA ST  NATOMA ST          25
# 4    4  106000     01ST        ST     NATOMA ST  HOWARD ST          25
#
#      L_mile                                           geometry street_y  ...  \
# 0  0.110859  LINESTRING (-122.41220 37.75583, -122.41205 37...           ...
# 1  0.042996  LINESTRING (-122.39603 37.78854, -122.39548 37...     01ST  ...
# 2  0.033369  LINESTRING (-122.39859 37.79057, -122.39816 37...     01ST  ...
# 3  0.035847  LINESTRING (-122.39703 37.78933, -122.39657 37...     01ST  ...
# 4  0.041568  LINESTRING (-122.39657 37.78896, -122.39603 37...     01ST  ...
#
#   TF_LANES FT_PARK TF_PARK  FT_SEG_STR   longitude   latitude Field3     AADT  \
# 0        0       0       0           3 -122.412183  37.755410   None    971.0
# 1        0       0       0           4 -122.395765  37.788340   None  30809.0
# 2        0       1       1           4 -122.398155  37.790235   None  35019.0
# 3        0       0       0           4 -122.396585  37.789000   None  33893.0
# 4        0       0       0           4 -122.396585  37.789000   None  33893.0
#
#   Shape_Length    Shape_Area
# 0     0.003611  2.342982e-07
# 1     0.001808  9.820555e-08
# 2     0.001491  7.888605e-08
# 3     0.001572  8.385906e-08
# 4     0.001762  9.533942e-08
#
# [5 rows x 35 columns]

# %%
# impute the missing speed limit
lts_data.loc[lts_data['speedlimit']>0].groupby(['FUNCTIONAL'])['speedlimit'].agg(pd.Series.mode)
# Out:
# FUNCTIONAL
#                   99
# living_street     25
# motorway          99
# motorway_link     99
# path              30
# primary           30
# primary_link      99
# residential       15
# secondary         25
# secondary_link    15
# tertiary          25
# tertiary_link     40
# trunk             25
# trunk_link        99
# unclassified      15
# Name: speedlimit, dtype: int64

# %%
#Define function for speed limit imputation
def speed_fun(FUNCTIONAL):
    if FUNCTIONAL=='living_street':
        return 25
    elif FUNCTIONAL=='motorway':
        return 99
    elif FUNCTIONAL=='motorway_link':
        return 99
    elif FUNCTIONAL=='path':
        return 30
    elif FUNCTIONAL=='primary':
        return 30
    elif FUNCTIONAL=='primary_link':
        return 30
    elif FUNCTIONAL=='residential':
        return 15
    elif FUNCTIONAL=='secondary':
        return 25
    elif FUNCTIONAL=='secondary_link':
        return 15
    elif FUNCTIONAL=='tertiary':
        return 25
    elif FUNCTIONAL=='tertiary_link':
        return 40
    elif FUNCTIONAL=='trunk':
        return 25
    elif FUNCTIONAL=='trunk_link':
        return 25
    elif FUNCTIONAL=='unclassified':
        return 15
    else:
        return 15

# %%
# separte the roads that have missing speed
ds=lts_data.loc[lts_data['speedlimit']<=0]
ds['speed']=ds.apply(lambda row:speed_fun(row['FUNCTIONAL']),axis=1)
# assign the speed for the road that have already speed
das=lts_data.loc[lts_data['speedlimit']>0]
das['speed']=das['speedlimit']
# now combine these above two files together
lts1=pd.concat([ds,das], axis=0)
lts1.shape
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# (16572, 36)

# %% [markdown]
# # Assign the missing number of lanes for each directions
#             lanes:
#                 - where: "functional_class IN ('primary','secondary')"
#                   val: 2
#                 - where: "functional_class IN ('tertiary')"
#                   val: 1
#                 - where: "functional_class IN ('unclassified','residential','living_street')"
#                   val: 0
#                 - else: 1

# %%
def lane_number(FUNCTIONAL):
    if FUNCTIONAL=='primary':
        return 2
    elif FUNCTIONAL=='secondary':
        return 2
    elif FUNCTIONAL=='tertiary':
        return 1
    elif FUNCTIONAL=='unclassified':
        return 1
    elif FUNCTIONAL=='residential':
        return 1
    elif FUNCTIONAL=='living_street':
        return 1
    else:
        return 1

# %%
ft_corr=lts1.loc[lts1['FT_LANES']<=0]
ft_corr['forward_lane_num']=ft_corr.apply(lambda row:lane_number(row['FUNCTIONAL']),axis=1 )
ft_non_corr=lts1.loc[lts1['FT_LANES']>0]
ft_non_corr['forward_lane_num']=ft_non_corr['FT_LANES']
ft_corr_al=pd.concat([ft_corr,ft_non_corr])
ft_corr_al.shape
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# (16572, 37)

# %%
ft_corr_al.groupby(['FUNCTIONAL'])['forward_lane_num'].count()
# Out:
# FUNCTIONAL
#                     368
# living_street        31
# motorway              5
# motorway_link        85
# path                204
# primary             632
# primary_link         50
# residential       10091
# secondary          1869
# secondary_link       10
# tertiary           2895
# tertiary_link         5
# trunk                67
# trunk_link            6
# unclassified        254
# Name: forward_lane_num, dtype: int64

# %%
tf_corr=ft_corr_al.loc[ft_corr_al['TF_LANES']<=0]
tf_corr['backward_lane_num']=tf_corr.apply(lambda row:lane_number(row['FUNCTIONAL']),axis=1 )
tf_non_corr=ft_corr_al.loc[ft_corr_al['TF_LANES']>0]
tf_non_corr['backward_lane_num']=tf_non_corr['TF_LANES']
tf_corr_al=pd.concat([tf_corr,tf_non_corr])
tf_corr_al.shape
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# (16572, 38)

# %%
tf_corr_al.groupby(['backward_lane_num'])['backward_lane_num'].count()
# Out:
# backward_lane_num
# 1    14035
# 2     2438
# 3       99
# Name: backward_lane_num, dtype: int64

# %%
lts2=tf_corr_al

# %%
# we successfuly imputed the speed based city provided shape file, now lets check the lane number,direction and centerline
def direction(forward_lane_num,backward_lane_num):
    if ((forward_lane_num>0)&(backward_lane_num>0)):
        return 2
    else:
        return 1
lts2['direction']=lts2.apply(lambda row:direction(row['forward_lane_num'], row['backward_lane_num']), axis=1) 
lts2.head()
# Out:
#     FID     cnn street_x st_type_x    from_st_x       to_st_x  speedlimit  \
# 16   16  129000     02ND        ST    MARKET ST  STEVENSON ST           0
# 19   19  121000     02ND       AVE  CORNWALL ST    CLEMENT ST           0
# 20   20  122000     02ND       AVE   CLEMENT ST    GEARY BLVD           0
# 22   22  128000     02ND       AVE      HUGO ST     IRVING ST           0
# 28   28  124000     02ND       AVE      ANZA ST     BALBOA ST           0
#
#       L_mile                                           geometry street_y  ...  \
# 16  0.043812  LINESTRING (-122.40138 37.78927, -122.40081 37...     02ND  ...
# 19  0.128947  LINESTRING (-122.46027 37.78501, -122.46014 37...     02ND  ...
# 20  0.133327  LINESTRING (-122.46014 37.78314, -122.46000 37...     02ND  ...
# 22  0.064843  LINESTRING (-122.45888 37.76530, -122.45882 37...     02ND  ...
# 28  0.127806  LINESTRING (-122.45986 37.77928, -122.45972 37...     02ND  ...
#
#      longitude   latitude Field3     AADT  Shape_Length    Shape_Area speed  \
# 16 -122.401120  37.789020   None  16526.0      0.001836  9.984372e-08    25
# 19 -122.460155  37.783260   None    465.0      0.004134  2.706863e-07    15
# 20 -122.460015  37.781220   None    529.0      0.004261  2.794707e-07    15
# 22 -122.458855  37.764825   None     40.0      0.002273  1.420066e-07    15
# 28 -122.459810  37.778350   None    785.0      0.004101  2.683780e-07    15
#
#     forward_lane_num backward_lane_num  direction
# 16                 1                 1          2
# 19                 1                 1          2
# 20                 1                 1          2
# 22                 1                 1          2
# 28                 1                 1          2
#
# [5 rows x 39 columns]

# %%
lts2.shape
# Out:
# (16572, 39)

# %% [markdown]
# # Assign the centerlines based on following assumption
#                 - where: "functional_class IN ('primary','secondary','tertiary')"
#                   val: True
#                 - where: "functional_class IN ('unclassified','residential','living_street')"
#                   val: False
#                 - else: True

# %%
# define centerline
def centerline(FUNCTIONAL):
    if FUNCTIONAL=='primary':
        return 1
    elif FUNCTIONAL=='secondary':
        return 1
    elif FUNCTIONAL=='tertiary':
        return 1
    elif FUNCTIONAL=='unclassified':
        return 0
    elif FUNCTIONAL=='residential':
        return 0   
    elif FUNCTIONAL=='living_street':
        return 0     
    else:
        return 0
lts2['centerline']=lts2.apply(lambda row: centerline(row['FUNCTIONAL']),axis=1)
lts2.head()
# Out:
#     FID     cnn street_x st_type_x    from_st_x       to_st_x  speedlimit  \
# 16   16  129000     02ND        ST    MARKET ST  STEVENSON ST           0
# 19   19  121000     02ND       AVE  CORNWALL ST    CLEMENT ST           0
# 20   20  122000     02ND       AVE   CLEMENT ST    GEARY BLVD           0
# 22   22  128000     02ND       AVE      HUGO ST     IRVING ST           0
# 28   28  124000     02ND       AVE      ANZA ST     BALBOA ST           0
#
#       L_mile                                           geometry street_y  ...  \
# 16  0.043812  LINESTRING (-122.40138 37.78927, -122.40081 37...     02ND  ...
# 19  0.128947  LINESTRING (-122.46027 37.78501, -122.46014 37...     02ND  ...
# 20  0.133327  LINESTRING (-122.46014 37.78314, -122.46000 37...     02ND  ...
# 22  0.064843  LINESTRING (-122.45888 37.76530, -122.45882 37...     02ND  ...
# 28  0.127806  LINESTRING (-122.45986 37.77928, -122.45972 37...     02ND  ...
#
#      latitude Field3     AADT  Shape_Length    Shape_Area speed  \
# 16  37.789020   None  16526.0      0.001836  9.984372e-08    25
# 19  37.783260   None    465.0      0.004134  2.706863e-07    15
# 20  37.781220   None    529.0      0.004261  2.794707e-07    15
# 22  37.764825   None     40.0      0.002273  1.420066e-07    15
# 28  37.778350   None    785.0      0.004101  2.683780e-07    15
#
#    forward_lane_num  backward_lane_num direction  centerline
# 16                1                  1         2           1
# 19                1                  1         2           0
# 20                1                  1         2           0
# 22                1                  1         2           0
# 28                1                  1         2           0
#
# [5 rows x 40 columns]

# %%
# Assign unique id
lts2['unique_id']=lts2.index

# %%
#https://pysal.org/scipy2019-intermediate-gds/deterministic/gds2-rasters.html
import rasterio
from rasterio.plot import show
from rasterio import plot as rioplot
import matplotlib.pyplot as plt

# %%
# Open the raster image
barea_slope = rasterio.open('H:/mmmiah/Desktop/Bicycle Connectivity Project/Project-Bicycle Connectivity/Bay Area_LTS/Slope/Slope/cslope11.img')
print(barea_slope.crs)
#rioplot.show(barea_slope)
# Out:
# EPSG:4269

# %%
# Reproject the geometries by replacing the values with projected ones
lts2 = lts2.to_crs(epsg=7131)
lts2['length']=lts2.length
lts_new = lts2.to_crs(epsg=4326)
lts_new.head(10)
# Out:
#     FID     cnn street_x st_type_x          from_st_x        to_st_x  \
# 16   16  129000     02ND        ST          MARKET ST   STEVENSON ST
# 19   19  121000     02ND       AVE        CORNWALL ST     CLEMENT ST
# 20   20  122000     02ND       AVE         CLEMENT ST     GEARY BLVD
# 22   22  128000     02ND       AVE            HUGO ST      IRVING ST
# 28   28  124000     02ND       AVE            ANZA ST      BALBOA ST
# 29   29  123000     02ND       AVE         GEARY BLVD        ANZA ST
# 30   30  119000     02ND       AVE            LAKE ST  CALIFORNIA ST
# 33   33  118000     02ND       AVE  START: 1-99 BLOCK        LAKE ST
# 37   37  125000     02ND       AVE          BALBOA ST    CABRILLO ST
# 40   40  130000     02ND        ST       STEVENSON ST      JESSIE ST
#
#     speedlimit    L_mile                                           geometry  \
# 16           0  0.043812  LINESTRING (-122.40138 37.78927, -122.40081 37...
# 19           0  0.128947  LINESTRING (-122.46027 37.78501, -122.46014 37...
# 20           0  0.133327  LINESTRING (-122.46014 37.78314, -122.46000 37...
# 22           0  0.064843  LINESTRING (-122.45888 37.76531, -122.45882 37...
# 28           0  0.127806  LINESTRING (-122.45986 37.77928, -122.45972 37...
# 29           0  0.133327  LINESTRING (-122.46000 37.78121, -122.45986 37...
# 30           0  0.091652  LINESTRING (-122.46040 37.78686, -122.46031 37...
# 33           0  0.026618  LINESTRING (-122.46043 37.78725, -122.46040 37...
# 37           0  0.128764  LINESTRING (-122.45972 37.77743, -122.45959 37...
# 40           0  0.036285  LINESTRING (-122.40081 37.78881, -122.40035 37...
#
#    street_y  ...     AADT Shape_Length    Shape_Area  speed  forward_lane_num  \
# 16     02ND  ...  16526.0     0.001836  9.984372e-08     25                 1
# 19     02ND  ...    465.0     0.004134  2.706863e-07     15                 1
# 20     02ND  ...    529.0     0.004261  2.794707e-07     15                 1
# 22     02ND  ...     40.0     0.002273  1.420066e-07     15                 1
# 28     02ND  ...    785.0     0.004101  2.683780e-07     15                 1
# 29     02ND  ...    529.0     0.004261  2.794635e-07     15                 1
# 30     02ND  ...    207.0     0.003051  1.958484e-07     15                 1
# 33     02ND  ...     64.0     0.001164  6.533321e-08     15                 1
# 37     02ND  ...    561.0     0.004129  2.702916e-07     15                 1
# 40     02ND  ...  16783.0     0.001586  8.473736e-08     25                 1
#
#    backward_lane_num direction  centerline unique_id      length
# 16                 1         2           1        16   70.508916
# 19                 1         2           0        19  207.521292
# 20                 1         2           0        20  214.571476
# 22                 1         2           0        22  104.356250
# 28                 1         2           0        28  205.686415
# 29                 1         2           0        29  214.571424
# 30                 1         2           0        30  147.501201
# 33                 1         2           0        33   42.837216
# 37                 1         2           0        37  207.227539
# 40                 1         2           1        40   58.396048
#
# [10 rows x 42 columns]

# %%
lts_new['unique_id'].nunique()
# Out:
# 16572

# %%
# get the slope for each link of the network
# %time
lts_new
# First identify the starting and ending node of each link
lts_new['starting point'] = None
lts_new['ending point'] = None

for index, row in lts_new.iterrows():
    coords = [(coords) for coords in list(row['geometry'].coords)]
    first_coord, last_coord = [ coords[i] for i in (0, -1) ]
    lts_new.at[index,'starting point'] = Point(first_coord)
    lts_new.at[index,'ending point'] = Point(last_coord)
    lts_new
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Calculate each link starting lat and long
sf1=lts_new.loc[:,["unique_id","starting point"]]
sf1.columns=["unique_id","geometry"]
sf1['start_lon'] = sf1.geometry.apply(lambda p: p.x)
sf1['start_lat'] = sf1.geometry.apply(lambda p: p.y)
sf2=sf1.loc[:,["unique_id","geometry","start_lon","start_lat"]]
sf2.head(5)
# Out:
#     unique_id                                        geometry   start_lon  \
# 16         16           POINT (-122.40137500000002 37.789265) -122.401375
# 19         19           POINT (-122.460266 37.78500699999999) -122.460266
# 20         20  POINT (-122.46014000000001 37.783139999999996) -122.460140
# 22         22           POINT (-122.45888 37.765305000000005) -122.458880
# 28         28            POINT (-122.45985999999999 37.77928) -122.459860
#
#     start_lat
# 16  37.789265
# 19  37.785007
# 20  37.783140
# 22  37.765305
# 28  37.779280

# %%
sf2.shape
# Out:
# (16572, 4)

# %%
# Calculate each link starting elevation
sf2["starting_ele"]= None
#point in test['geometry']:
x = sf2["start_lon"]
y = sf2["start_lat"]
row, col = barea_slope.index(x,y)
sf2["starting_ele"]=barea_slope.read(1)[row,col]

# %%
# %%time
# Calculate each link end point elevation
ef1=lts_new.loc[:,["unique_id","ending point"]]
ef1.columns=["unique_id","geometry"]
ef1['end_lon'] = ef1.geometry.apply(lambda p: p.x)
ef1['end_lat'] = ef1.geometry.apply(lambda p: p.y)
ef2=ef1.loc[:,["unique_id","geometry","end_lon","end_lat"]]
ef2.head(5)
# Out:
# CPU times: total: 219 ms
# Wall time: 214 ms
#     unique_id                                        geometry     end_lon  \
# 16         16           POINT (-122.40081000000002 37.788815) -122.400810
# 19         19  POINT (-122.46014000000001 37.783139999999996) -122.460140
# 20         20                        POINT (-122.46 37.78121) -122.460000
# 22         22            POINT (-122.45882 37.76436600000001) -122.458820
# 28         28          POINT (-122.459724 37.777429999999995) -122.459724
#
#       end_lat
# 16  37.788815
# 19  37.783140
# 20  37.781210
# 22  37.764366
# 28  37.777430

# %%
ef2['unique_id'].nunique()
# Out:
# 16572

# %%
# %%time
# Calculate the each link end elevation
ef2["ending_ele"]= None
#point in test['geometry']:
x = ef2["end_lon"]
y = ef2["end_lat"]
row, col = barea_slope.index(x,y)
ef2["ending_ele"]=barea_slope.read(1)[row,col]
# Out:
# CPU times: total: 4.62 s
# Wall time: 4.62 s

# %%
# %%time
# Calculate the slope for each link
from functools import reduce
barea_all=[sf2,ef2,lts_new]

barea_all1= reduce(lambda  left,right: pd.merge(left,right,on=['unique_id'],
                                            how='outer'), barea_all).fillna('0')
barea_all1["slope"]=abs((barea_all1['starting_ele']-barea_all1['ending_ele'])/barea_all1['length'])*100
barea_all1=barea_all1.drop_duplicates(subset=['unique_id'], keep='first')
barea_all1.head()
# Out:
# CPU times: total: 203 ms
# Wall time: 201 ms
#    unique_id                                      geometry_x   start_lon  \
# 0         16           POINT (-122.40137500000002 37.789265) -122.401375
# 1         19           POINT (-122.460266 37.78500699999999) -122.460266
# 2         20  POINT (-122.46014000000001 37.783139999999996) -122.460140
# 3         22           POINT (-122.45888 37.765305000000005) -122.458880
# 4         28            POINT (-122.45985999999999 37.77928) -122.459860
#
#    start_lat  starting_ele                                      geometry_y  \
# 0  37.789265             9           POINT (-122.40081000000002 37.788815)
# 1  37.785007            58  POINT (-122.46014000000001 37.783139999999996)
# 2  37.783140            59                        POINT (-122.46 37.78121)
# 3  37.765305            91            POINT (-122.45882 37.76436600000001)
# 4  37.779280            62          POINT (-122.459724 37.777429999999995)
#
#       end_lon    end_lat  ending_ele  FID  ...    Shape_Area speed  \
# 0 -122.400810  37.788815           9   16  ...  9.984372e-08    25
# 1 -122.460140  37.783140          59   19  ...  2.706863e-07    15
# 2 -122.460000  37.781210          60   20  ...  2.794707e-07    15
# 3 -122.458820  37.764366          97   22  ...  1.420066e-07    15
# 4 -122.459724  37.777430          63   28  ...  2.683780e-07    15
#
#   forward_lane_num backward_lane_num direction  centerline      length  \
# 0                1                 1         2           1   70.508916
# 1                1                 1         2           0  207.521292
# 2                1                 1         2           0  214.571476
# 3                1                 1         2           0  104.356250
# 4                1                 1         2           0  205.686415
#
#                                    starting point  \
# 0           POINT (-122.40137500000002 37.789265)
# 1           POINT (-122.460266 37.78500699999999)
# 2  POINT (-122.46014000000001 37.783139999999996)
# 3           POINT (-122.45888 37.765305000000005)
# 4            POINT (-122.45985999999999 37.77928)
#
#                                      ending point     slope
# 0           POINT (-122.40081000000002 37.788815)  0.000000
# 1  POINT (-122.46014000000001 37.783139999999996)  0.481878
# 2                        POINT (-122.46 37.78121)  0.466045
# 3            POINT (-122.45882 37.76436600000001)  5.749536
# 4          POINT (-122.459724 37.777429999999995)  0.486177
#
# [5 rows x 53 columns]

# %%
sf2.shape,ef2.shape,lts_new.shape,barea_all1.shape
# Out:
# ((16572, 5), (16572, 5), (16572, 44), (16572, 53))

# %%
barea_all1.shape
# Out:
# (16572, 53)

# %%
barea_all2=barea_all1.drop(['geometry_x',
 'start_lon',
 'start_lat',
 'starting_ele',
 'geometry_y',
 'end_lon',
 'end_lat', 'starting point',
 'ending point'],axis=1)

# %%
list(barea_all2)
# Out:
# ['unique_id',
#  'ending_ele',
#  'FID',
#  'cnn',
#  'street_x',
#  'st_type_x',
#  'from_st_x',
#  'to_st_x',
#  'speedlimit',
#  'L_mile',
#  'geometry',
#  'street_y',
#  'st_type_y',
#  'from_st_y',
#  'to_st_y',
#  'speedlimit_y',
#  'ROAD_ID',
#  'OSMID',
#  'FUNCTIONAL',
#  'PATH_ID',
#  'ONE_WAY',
#  'INTERSECTI',
#  'INTERSE_01',
#  'WIDTH',
#  'FT_BIKE_IN',
#  'TF_BIKE_IN',
#  'FT_LANES',
#  'TF_LANES',
#  'FT_PARK',
#  'TF_PARK',
#  'FT_SEG_STR',
#  'longitude',
#  'latitude',
#  'Field3',
#  'AADT',
#  'Shape_Length',
#  'Shape_Area',
#  'speed',
#  'forward_lane_num',
#  'backward_lane_num',
#  'direction',
#  'centerline',
#  'length',
#  'slope']

# %%
barea_all2['slope'].describe()
# Out:
# count    1.657200e+04
# mean     5.129813e+06
# std      1.284642e+08
# min      0.000000e+00
# 25%      1.058944e+00
# 50%      2.986471e+00
# 75%      6.542119e+00
# max      9.016329e+09
# Name: slope, dtype: float64

# %%
slope1=barea_all2.loc[barea_all2['slope']<=2.0]
slope2=barea_all2[(barea_all2['slope']>2.0) &(barea_all2['slope']<=4.0) ]
slope3=barea_all2[(barea_all2['slope']>4.0) &(barea_all2['slope']<=6.0) ]
slope4=barea_all2.loc[barea_all2['slope']>6.0]
print('length of roads for slope 0-2:',slope1['length'].sum()*0.000621371)
print('length of roads for slope 2-4:',slope2['length'].sum()*0.000621371)
print('length of roads for slope 4-6:',slope3['length'].sum()*0.000621371)
print('length of roads for slope >6:',slope4['length'].sum()*0.000621371)
# Out:
# length of roads for slope 0-2: 554.8956360260169
# length of roads for slope 2-4: 263.0486993427551
# length of roads for slope 4-6: 164.24196476851216
# length of roads for slope >6: 302.0840733838671

# %%
# Exclusive_bn=bnetw.loc[bnetw['Network_Type']=='Exclusive_Bike_Network']
# Exclusive_bn.shape

# %%
# bike_mixed=bnetw.loc[bnetw['Network_Type']=='Bike_Traffic_Mixed_Network']
# bike_mixed.shape

# %%
# save this mixed traffic network file
crs = {'init': 'epsg:4326'}
mixtraffic = gpd.GeoDataFrame(barea_all2, crs=crs, geometry = 'geometry')
mixtraffic.to_file("mixed_traffic_network.json", driver="GeoJSON")
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# # Now Prepare Bike lane data

# %%
# read the bike network
bnetw=gpd.read_file('H:/mmmiah/Desktop/Bicycle Connectivity Project/SF Validation_data/Data From Jane/Data_Sept 13/bike_network_sep17.json', driver="GeoJSON")
bnetw.head()
# Out:
#    FID  objectid  cnn streetname from_st to_st facility_t direct surface_tr  \
# 0    0      1652    0                             CLASS I     2W
# 1    1      4773    0                             CLASS I     2W
# 2    2      1688    0                             CLASS I     2W
# 3    3      3319    0                             CLASS I     2W
# 4    4       583    0                             CLASS I     2W
#
#   barrier  ... schoolzo_2 status  workorder  OBJECTID   longitude   latitude  \
# 0          ...          0                           1         NaN        NaN
# 1          ...          0                           2         NaN        NaN
# 2          ...          0                           3 -122.455341  37.770499
# 3          ...          0                           4         NaN        NaN
# 4          ...          0                           5 -122.447280  37.771885
#
#    Field3     AADT  Shape_Length  \
# 0    None      NaN      0.008418
# 1    None      NaN      0.005905
# 2    None  10721.0      0.004300
# 3    None      NaN      0.004923
# 4    None  11748.0      0.002176
#
#                                             geometry
# 0  POLYGON ((-122.50279 37.70799, -122.50279 37.7...
# 1  POLYGON ((-122.51086 37.78276, -122.51087 37.7...
# 2  POLYGON ((-122.45376 37.77002, -122.45375 37.7...
# 3  POLYGON ((-122.50265 37.71867, -122.50264 37.7...
# 4  POLYGON ((-122.44743 37.77187, -122.44743 37.7...
#
# [5 rows x 86 columns]

# %%
ft_corrb=bnetw.loc[bnetw['FT_LANES']<=0]
ft_corrb['forward_lane_num']=ft_corrb.apply(lambda row:lane_number(row['FUNCTIONAL']),axis=1 )
ft_non_corrb=bnetw.loc[bnetw['FT_LANES']>0]
ft_non_corrb['forward_lane_num']=ft_non_corrb['FT_LANES']
bnetw1=pd.concat([ft_corrb,ft_non_corrb])
bnetw1.shape
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# (5408, 87)

# %%
# assign the lane number from OSM
tf_corrb=bnetw1.loc[bnetw1['TF_LANES']<=0]
tf_corrb['backward_lane_num']=tf_corrb.apply(lambda row:lane_number(row['FUNCTIONAL']),axis=1 )
tf_non_corrb=bnetw1.loc[bnetw1['TF_LANES']>0]
tf_non_corrb['backward_lane_num']=tf_non_corrb['TF_LANES']
bnetw2=pd.concat([tf_corrb,tf_non_corrb])
bnetw2.shape
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# (5408, 88)

# %%
bnetw2['direction']=np.where(bnetw2['direct'].str.contains('2W'),2,1)
bnetw2.head()
# Out:
#    FID  objectid  cnn streetname from_st to_st facility_t direct surface_tr  \
# 0    0      1652    0                             CLASS I     2W
# 1    1      4773    0                             CLASS I     2W
# 3    3      3319    0                             CLASS I     2W
# 4    4       583    0                             CLASS I     2W
# 5    5      3670    0                             CLASS I     2W
#
#   barrier  ... OBJECTID  longitude   latitude  Field3     AADT Shape_Length  \
# 0          ...        1        NaN        NaN    None      NaN     0.008418
# 1          ...        2        NaN        NaN    None      NaN     0.005905
# 3          ...        4        NaN        NaN    None      NaN     0.004923
# 4          ...        5 -122.44728  37.771885    None  11748.0     0.002176
# 5          ...        6        NaN        NaN    None      NaN     0.002026
#
#                                             geometry forward_lane_num  \
# 0  POLYGON ((-122.50279 37.70799, -122.50279 37.7...                1
# 1  POLYGON ((-122.51086 37.78276, -122.51087 37.7...                1
# 3  POLYGON ((-122.50265 37.71867, -122.50264 37.7...                1
# 4  POLYGON ((-122.44743 37.77187, -122.44743 37.7...                1
# 5  POLYGON ((-122.50338 37.71294, -122.50339 37.7...                1
#
#    backward_lane_num  direction
# 0                  1          2
# 1                  1          2
# 3                  1          2
# 4                  1          2
# 5                  1          2
#
# [5 rows x 89 columns]

# %%
bnetw2['direct'].unique()
# Out:
# array(['2W', '1W', ' ', 'N'], dtype=object)

# %%
# separte the roads that have missing speed
dsb=bnetw2.loc[bnetw2['speedlimit']<=0]
dsb['speed']=dsb.apply(lambda row:speed_fun(row['FUNCTIONAL']),axis=1)
# assign the speed for the road that have already speed
dasb=bnetw2.loc[bnetw2['speedlimit']>0]
dasb['speed']=dasb['speedlimit']
# now combine these above two files together
bnetw3=pd.concat([dsb,dasb], axis=0)
bnetw3.shape
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# (5408, 90)

# %%
dsb.shape,dasb.shape
# Out:
# ((5030, 90), (378, 90))

# %%
def network_type(cnn):
    if cnn==0:
        return 'Exclusive_Bike_Network'
    else:
        return 'Bike_Traffic_Mixed_Network'
bnetw3['Network_Type']=bnetw3.apply(lambda row: network_type(row['cnn']),axis=1)
bnetw3.head()
# Out:
#    FID  objectid  cnn streetname from_st to_st facility_t direct surface_tr  \
# 0    0      1652    0                             CLASS I     2W
# 1    1      4773    0                             CLASS I     2W
# 3    3      3319    0                             CLASS I     2W
# 4    4       583    0                             CLASS I     2W
# 5    5      3670    0                             CLASS I     2W
#
#   barrier  ...   latitude Field3     AADT  Shape_Length  \
# 0          ...        NaN   None      NaN      0.008418
# 1          ...        NaN   None      NaN      0.005905
# 3          ...        NaN   None      NaN      0.004923
# 4          ...  37.771885   None  11748.0      0.002176
# 5          ...        NaN   None      NaN      0.002026
#
#                                             geometry forward_lane_num  \
# 0  POLYGON ((-122.50279 37.70799, -122.50279 37.7...                1
# 1  POLYGON ((-122.51086 37.78276, -122.51087 37.7...                1
# 3  POLYGON ((-122.50265 37.71867, -122.50264 37.7...                1
# 4  POLYGON ((-122.44743 37.77187, -122.44743 37.7...                1
# 5  POLYGON ((-122.50338 37.71294, -122.50339 37.7...                1
#
#    backward_lane_num direction  speed            Network_Type
# 0                  1         2     15  Exclusive_Bike_Network
# 1                  1         2     30  Exclusive_Bike_Network
# 3                  1         2     15  Exclusive_Bike_Network
# 4                  1         2     30  Exclusive_Bike_Network
# 5                  1         2     15  Exclusive_Bike_Network
#
# [5 rows x 91 columns]

# %%
bnetw3['symbology'].unique()
# Out:
# array(['BIKE PATH', 'BIKE ROUTE', 'BIKE LANE', 'SEPARATED BIKEWAY',
#        'NEIGHBORWAY'], dtype=object)

# %%
bnetw3['barrier'].unique()
# Out:
# array([' ', 'CONCRETE', 'PARKING; SAFE-HIT POSTS', 'SAFE-HIT POSTS',
#        'PARKING', 'CONCRETE; SAFE-HIT POSTS',
#        'CONCRETE; PARKING; SAFE-HIT POSTS', 'CONCRETE; PARKING',
#        'BACK-IN ANGLED PARKING', 'SAFE-HIT POSTS; PARKING',
#        'PARKING; SAFE-HIT POST',
#        'PARKING; SAFE-HIT POST; CONCRETE ISLAND',
#        'SAFE-HIT POSTS; BIKE SHARE STATION', 'SAFE-HIT POST', 'K-RAIL',
#        'PARKING; WALKWAY; SAFE-HIT POSTS',
#        'CONCRETE; SAFE-HIT POSTS; BIKE SHARE STATION',
#        'PARKING; CONCRETE; SAFE-HIT POSTS', 'SAFE-HIT POSTS; K-RAIL',
#        'PARKING; SAFE-HIT POSTS; BIKE SHARE STATIONS',
#        'PARKING; CONCRETE ISLAND', 'CURB',
#        'CONCRETE ISLAND; SAFE-HIT POSTS',
#        'SAFE-HIT POSTS; CONCRETE ISLAND',
#        'PARKING; SAFE-HIT POSTS; CONCRETE ISLAND',
#        'SAFE HIT POSTS; CONCRETE ISLAND',
#        'PARKING; SAFE-HIT POSTS; CONCRETE', 'PARKING;  SAFE-HIT POSTS',
#        'SAFE-HIT POSTS; CONCRETE'], dtype=object)

# %%
# define Parking lane
bnetw3['parking_lane'] = np.where(bnetw3['barrier'].str.contains('PARKING'),1,0)
bnetw3.head()
# Out:
#    FID  objectid  cnn streetname from_st to_st facility_t direct surface_tr  \
# 0    0      1652    0                             CLASS I     2W
# 1    1      4773    0                             CLASS I     2W
# 3    3      3319    0                             CLASS I     2W
# 4    4       583    0                             CLASS I     2W
# 5    5      3670    0                             CLASS I     2W
#
#   barrier  ... Field3     AADT  Shape_Length  \
# 0          ...   None      NaN      0.008418
# 1          ...   None      NaN      0.005905
# 3          ...   None      NaN      0.004923
# 4          ...   None  11748.0      0.002176
# 5          ...   None      NaN      0.002026
#
#                                             geometry  forward_lane_num  \
# 0  POLYGON ((-122.50279 37.70799, -122.50279 37.7...                 1
# 1  POLYGON ((-122.51086 37.78276, -122.51087 37.7...                 1
# 3  POLYGON ((-122.50265 37.71867, -122.50264 37.7...                 1
# 4  POLYGON ((-122.44743 37.77187, -122.44743 37.7...                 1
# 5  POLYGON ((-122.50338 37.71294, -122.50339 37.7...                 1
#
#   backward_lane_num  direction speed            Network_Type  parking_lane
# 0                 1          2    15  Exclusive_Bike_Network             0
# 1                 1          2    30  Exclusive_Bike_Network             0
# 3                 1          2    15  Exclusive_Bike_Network             0
# 4                 1          2    30  Exclusive_Bike_Network             0
# 5                 1          2    15  Exclusive_Bike_Network             0
#
# [5 rows x 92 columns]

# %%
# Assign bike lane width
#https://sfgov.org/sfc/bac/bicycle-plan-part-5
def bike_length(symbology):
    if (symbology=='BIKE PATH'):
        return 8
    elif (symbology=='BIKE ROUTE'):
        return 12
    elif (symbology=='BIKE LANE'):
        return 6
#https://dot.ca.gov/-/media/dot-media/programs/design/documents/dib-89-01_kf-a11y.pdf
    elif (symbology=='SEPARATED BIKEWAY'):
        return 7
#https://www.sfbetterstreets.org/design-guidelines/sidewalk-width/#sidewalkWidthTable
    elif (symbology=='NEIGHBORWAY'):
        return 10
    else:
        return 8
bnetw3['bike_lane_width']=bnetw3.apply(lambda row:bike_length(row['symbology']),axis=1)
bnetw3.head()
# Out:
#    FID  objectid  cnn streetname from_st to_st facility_t direct surface_tr  \
# 0    0      1652    0                             CLASS I     2W
# 1    1      4773    0                             CLASS I     2W
# 3    3      3319    0                             CLASS I     2W
# 4    4       583    0                             CLASS I     2W
# 5    5      3670    0                             CLASS I     2W
#
#   barrier  ...     AADT Shape_Length  \
# 0          ...      NaN     0.008418
# 1          ...      NaN     0.005905
# 3          ...      NaN     0.004923
# 4          ...  11748.0     0.002176
# 5          ...      NaN     0.002026
#
#                                             geometry  forward_lane_num  \
# 0  POLYGON ((-122.50279 37.70799, -122.50279 37.7...                 1
# 1  POLYGON ((-122.51086 37.78276, -122.51087 37.7...                 1
# 3  POLYGON ((-122.50265 37.71867, -122.50264 37.7...                 1
# 4  POLYGON ((-122.44743 37.77187, -122.44743 37.7...                 1
# 5  POLYGON ((-122.50338 37.71294, -122.50339 37.7...                 1
#
#    backward_lane_num direction  speed            Network_Type  parking_lane  \
# 0                  1         2     15  Exclusive_Bike_Network             0
# 1                  1         2     30  Exclusive_Bike_Network             0
# 3                  1         2     15  Exclusive_Bike_Network             0
# 4                  1         2     30  Exclusive_Bike_Network             0
# 5                  1         2     15  Exclusive_Bike_Network             0
#
#    bike_lane_width
# 0                8
# 1                8
# 3                8
# 4                8
# 5                8
#
# [5 rows x 93 columns]

# %%
def parking_lane(parking_lane):
    if parking_lane==1:
        return 8
    else:
        return 0
bnetw3['bike_lane_reach_width']=bnetw3.apply(lambda row:parking_lane(row['parking_lane']),axis=1)
bnetw3.head()
# Out:
#    FID  objectid  cnn streetname from_st to_st facility_t direct surface_tr  \
# 0    0      1652    0                             CLASS I     2W
# 1    1      4773    0                             CLASS I     2W
# 3    3      3319    0                             CLASS I     2W
# 4    4       583    0                             CLASS I     2W
# 5    5      3670    0                             CLASS I     2W
#
#   barrier  ... Shape_Length  \
# 0          ...     0.008418
# 1          ...     0.005905
# 3          ...     0.004923
# 4          ...     0.002176
# 5          ...     0.002026
#
#                                             geometry  forward_lane_num  \
# 0  POLYGON ((-122.50279 37.70799, -122.50279 37.7...                 1
# 1  POLYGON ((-122.51086 37.78276, -122.51087 37.7...                 1
# 3  POLYGON ((-122.50265 37.71867, -122.50264 37.7...                 1
# 4  POLYGON ((-122.44743 37.77187, -122.44743 37.7...                 1
# 5  POLYGON ((-122.50338 37.71294, -122.50339 37.7...                 1
#
#    backward_lane_num  direction speed            Network_Type parking_lane  \
# 0                  1          2    15  Exclusive_Bike_Network            0
# 1                  1          2    30  Exclusive_Bike_Network            0
# 3                  1          2    15  Exclusive_Bike_Network            0
# 4                  1          2    30  Exclusive_Bike_Network            0
# 5                  1          2    15  Exclusive_Bike_Network            0
#
#    bike_lane_width  bike_lane_reach_width
# 0                8                      0
# 1                8                      0
# 3                8                      0
# 4                8                      0
# 5                8                      0
#
# [5 rows x 94 columns]

# %%
bnetw3=bnetw3.drop(['geometry'],axis=1)

# %%
# read bike polyline shape file
bply=gpd.read_file('H:/mmmiah/Desktop/Bicycle Connectivity Project/SF Validation_data/MTA.bikewaynetwork/geo_export_a1e39e89-170f-4d40-866d-7f03d9a47948.shp')
bply = bply.to_crs(epsg=4326)
bply1=bply.drop(['cnn',
 'streetname',
 'from_st',
 'to_st',
 'facility_t',
 'direct',
 'surface_tr',
 'barrier',
 'notes',
 'dir',
 'double',
 'fy',
 'qtr',
 'street_',
 'length',
 'number_',
 'install_yr',
 'install_mo',
 'update_yr',
 'update_mo',
 'globalid',
 'symbology',
 'sharrow',
 'buffered',
 'raised',
 'contraflow',
 'greenwave',
 'biap',
 'sm_sweeper'],axis=1)

# %%
bply.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bnetw4=pd.merge(bnetw3, bply, on=['objectid'], how='inner')
bnetw4.head()
# Out:
#    FID  objectid  cnn_x streetname_x from_st_x to_st_x facility_t_x direct_x  \
# 0    0      1652      0                                     CLASS I       2W
# 1    1      4773      0                                     CLASS I       2W
# 2    3      3319      0                                     CLASS I       2W
# 3    4       583      0                                     CLASS I       2W
# 4    5      3670      0                                     CLASS I       2W
#
#   surface_tr_x barrier_x  ... symbology_y sharrow_y  buffered_y  raised_y  \
# 0                         ...   BIKE PATH       0.0          NO        NO
# 1                         ...   BIKE PATH       0.0          NO        NO
# 2                         ...   BIKE PATH       0.0          NO        NO
# 3                         ...   BIKE PATH       0.0          NO        NO
# 4                         ...   BIKE PATH       0.0          NO        NO
#
#    contraflow_y greenwave_y  biap_y sm_sweeper_y    L_mile  \
# 0            NO          NO      NO           NO  0.267051
# 1            NO          NO      NO           NO  0.155166
# 2            NO          NO      NO           NO  0.143260
# 3            NO          NO      NO           NO  0.056055
# 4            NO          NO      NO           NO  0.039456
#
#                                             geometry
# 0  LINESTRING (-122.50269 37.70797, -122.50214 37...
# 1  LINESTRING (-122.51093 37.78270, -122.51077 37...
# 2  LINESTRING (-122.50256 37.71871, -122.50258 37...
# 3  LINESTRING (-122.44733 37.77189, -122.44736 37...
# 4  LINESTRING (-122.50338 37.71286, -122.50266 37...
#
# [5 rows x 124 columns]

# %%
# Now calculate the slope
bnetw4.crs = {'init' :'epsg:4326'}
bnetw4 = gpd.GeoDataFrame(bnetw4, geometry='geometry') 
bnetw4 = bnetw4.to_crs(epsg=7131)
bnetw4['length']=bnetw4.length
bnetw4 = bnetw4.to_crs(epsg=4326)
bnetw4.head(10)
# Out:
# C:\Users\mmmiah\AppData\Local\Temp\ipykernel_13980\3469176368.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   bnetw4.crs = {'init' :'epsg:4326'}
#    FID  objectid  cnn_x streetname_x    from_st_x                   to_st_x  \
# 0    0      1652      0
# 1    1      4773      0
# 2    3      3319      0
# 3    4       583      0
# 4    5      3670      0
# 5    6      3371      0               LINCOLN WAY  MARTIN LUTHER KING JR DR
# 6    7      4394      0
# 7    8      2553      0
# 8    9      4228      0
# 9   10       864      0
#
#   facility_t_x direct_x surface_tr_x barrier_x  ... sharrow_y buffered_y  \
# 0      CLASS I       2W                         ...       0.0         NO
# 1      CLASS I       2W                         ...       0.0         NO
# 2      CLASS I       2W                         ...       0.0         NO
# 3      CLASS I       2W                         ...       0.0         NO
# 4      CLASS I       2W                         ...       0.0         NO
# 5      CLASS I       2W                         ...       0.0         NO
# 6      CLASS I       2W                         ...       0.0         NO
# 7      CLASS I       2W                         ...       0.0         NO
# 8      CLASS I       2W                         ...       0.0         NO
# 9      CLASS I       2W                         ...       0.0         NO
#
#    raised_y  contraflow_y  greenwave_y biap_y  sm_sweeper_y    L_mile  \
# 0        NO            NO           NO     NO            NO  0.267051
# 1        NO            NO           NO     NO            NO  0.155166
# 2        NO            NO           NO     NO            NO  0.143260
# 3        NO            NO           NO     NO            NO  0.056055
# 4        NO            NO           NO     NO            NO  0.039456
# 5        NO            NO           NO     NO            NO  0.035696
# 6        NO            NO           NO     NO            NO  0.179803
# 7        NO            NO           NO     NO            NO  0.164610
# 8        NO            NO           NO     NO            NO  0.193993
# 9        NO            NO           NO     NO            NO  0.467787
#
#                                             geometry      length
# 0  LINESTRING (-122.50269 37.70797, -122.50214 37...  429.780898
# 1  LINESTRING (-122.51093 37.78270, -122.51077 37...  249.717031
# 2  LINESTRING (-122.50256 37.71871, -122.50258 37...  230.555997
# 3  LINESTRING (-122.44733 37.77189, -122.44736 37...   90.213100
# 4  LINESTRING (-122.50338 37.71286, -122.50266 37...   63.499582
# 5  LINESTRING (-122.47826 37.76591, -122.47833 37...   57.447514
# 6  LINESTRING (-122.49948 37.71249, -122.50004 37...  289.367486
# 7  LINESTRING (-122.50010 37.71808, -122.50012 37...  264.916973
# 8  LINESTRING (-122.50399 37.71688, -122.50397 37...  312.204990
# 9  LINESTRING (-122.44896 37.77227, -122.44890 37...  752.836915
#
# [10 rows x 125 columns]

# %%
# Assign unique id
bnetw4['unique_id']=bnetw4.index

# %%
# get the slope for each link of the network
# %time
# First identify the starting and ending node of each link
bnetw4['starting point'] = None
bnetw4['ending point'] = None

for index, row in bnetw4.iterrows():
    coords = [(coords) for coords in list(row['geometry'].coords)]
    first_coord, last_coord = [ coords[i] for i in (0, -1) ]
    bnetw4.at[index,'starting point'] = Point(first_coord)
    bnetw4.at[index,'ending point'] = Point(last_coord)
    bnetw4
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Calculate each link starting lat and long
sf1b=bnetw4.loc[:,["unique_id","starting point"]]
sf1b.columns=["unique_id","geometry"]
sf1b['start_lon'] = sf1b.geometry.apply(lambda p: p.x)
sf1b['start_lat'] = sf1b.geometry.apply(lambda p: p.y)
sf2b=sf1b.loc[:,["unique_id","geometry","start_lon","start_lat"]]
sf2b.head(5)
# Out:
#    unique_id                               geometry   start_lon  start_lat
# 0          0   POINT (-122.50269000000002 37.70797) -122.502690  37.707970
# 1          1  POINT (-122.510925 37.78269999999999) -122.510925  37.782700
# 2          2            POINT (-122.50256 37.71871) -122.502560  37.718710
# 3          3            POINT (-122.44733 37.77189) -122.447330  37.771890
# 4          4  POINT (-122.50338000000002 37.712856) -122.503380  37.712856

# %%
# Calculate each link starting elevation
sf2b["starting_ele"]= None
#point in test['geometry']:
x = sf2b["start_lon"]
y = sf2b["start_lat"]
row, col = barea_slope.index(x,y)
sf2b["starting_ele"]=barea_slope.read(1)[row,col]

# %%
# %%time
# Calculate each link end point elevation
ef1b=bnetw4.loc[:,["unique_id","ending point"]]
ef1b.columns=["unique_id","geometry"]
ef1b['end_lon'] = ef1b.geometry.apply(lambda p: p.x)
ef1b['end_lat'] = ef1b.geometry.apply(lambda p: p.y)
ef2b=ef1b.loc[:,["unique_id","geometry","end_lon","end_lat"]]
ef2b.head(5)
# Out:
# CPU times: total: 125 ms
# Wall time: 116 ms
#    unique_id                               geometry     end_lon    end_lat
# 0          0  POINT (-122.50229000000002 37.711765) -122.502290  37.711765
# 1          1           POINT (-122.509476 37.78341) -122.509476  37.783410
# 2          2  POINT (-122.50235000000002 37.720554) -122.502350  37.720554
# 3          3  POINT (-122.44737999999998 37.772617) -122.447380  37.772617
# 4          4  POINT (-122.50265999999999 37.712868) -122.502660  37.712868

# %%
# %%time
# Calculate the each link end elevation
ef2b["ending_ele"]= None
#point in test['geometry']:
x = ef2b["end_lon"]
y = ef2b["end_lat"]
row, col = barea_slope.index(x,y)
ef2b["ending_ele"]=barea_slope.read(1)[row,col]
# Out:
# CPU times: total: 4.83 s
# Wall time: 4.85 s

# %%
# %%time
# Calculate the slope for each link
from functools import reduce
barea_allb=[sf2b,ef2b,bnetw4]

barea_all1b= reduce(lambda  left,right: pd.merge(left,right,on=['unique_id'],
                                            how='outer'), barea_allb).fillna('0')
barea_all1b["slope"]=abs((barea_all1b['starting_ele']-barea_all1b['ending_ele'])/barea_all1b['length'])*100
barea_all1b=barea_all1b.drop_duplicates(subset=['unique_id'], keep='first')
barea_all1b.head()
# Out:
# CPU times: total: 219 ms
# Wall time: 219 ms
#    unique_id                             geometry_x   start_lon  start_lat  \
# 0          0   POINT (-122.50269000000002 37.70797) -122.502690  37.707970
# 1          1  POINT (-122.510925 37.78269999999999) -122.510925  37.782700
# 2          2            POINT (-122.50256 37.71871) -122.502560  37.718710
# 3          3            POINT (-122.44733 37.77189) -122.447330  37.771890
# 4          4  POINT (-122.50338000000002 37.712856) -122.503380  37.712856
#
#    starting_ele                             geometry_y     end_lon    end_lat  \
# 0    2147483647  POINT (-122.50229000000002 37.711765) -122.502290  37.711765
# 1            70           POINT (-122.509476 37.78341) -122.509476  37.783410
# 2            51  POINT (-122.50235000000002 37.720554) -122.502350  37.720554
# 3            73  POINT (-122.44737999999998 37.772617) -122.447380  37.772617
# 4            15  POINT (-122.50265999999999 37.712868) -122.502660  37.712868
#
#    ending_ele  FID  ...  contraflow_y  greenwave_y biap_y sm_sweeper_y  \
# 0          23    0  ...            NO           NO     NO           NO
# 1          82    1  ...            NO           NO     NO           NO
# 2          43    3  ...            NO           NO     NO           NO
# 3          73    4  ...            NO           NO     NO           NO
# 4          33    5  ...            NO           NO     NO           NO
#
#      L_mile                                           geometry      length  \
# 0  0.267051  LINESTRING (-122.50269 37.70797, -122.50214 37...  429.780898
# 1  0.155166  LINESTRING (-122.51093 37.78270, -122.51077 37...  249.717031
# 2  0.143260  LINESTRING (-122.50256 37.71871, -122.50258 37...  230.555997
# 3  0.056055  LINESTRING (-122.44733 37.77189, -122.44736 37...   90.213100
# 4  0.039456  LINESTRING (-122.50338 37.71286, -122.50266 37...   63.499582
#
#                           starting point  \
# 0   POINT (-122.50269000000002 37.70797)
# 1  POINT (-122.510925 37.78269999999999)
# 2            POINT (-122.50256 37.71871)
# 3            POINT (-122.44733 37.77189)
# 4  POINT (-122.50338000000002 37.712856)
#
#                             ending point         slope
# 0  POINT (-122.50229000000002 37.711765)  4.996694e+08
# 1           POINT (-122.509476 37.78341)  4.805439e+00
# 2  POINT (-122.50235000000002 37.720554)  3.469873e+00
# 3  POINT (-122.44737999999998 37.772617)  0.000000e+00
# 4  POINT (-122.50265999999999 37.712868)  2.834664e+01
#
# [5 rows x 137 columns]

# %%
barea_all1b['slope'].describe()
# Out:
# count    5.408000e+03
# mean     5.823363e+06
# std      1.297451e+08
# min      0.000000e+00
# 25%      7.035734e-01
# 50%      2.069312e+00
# 75%      4.197010e+00
# max      4.217675e+09
# Name: slope, dtype: float64

# %%
barea_all2b=barea_all1b.drop(['geometry_x',
 'start_lon',
 'start_lat',
 'starting_ele',
 'geometry_y',
 'end_lon',
 'end_lat', 'starting point',
 'ending point'],axis=1)

# %%
barea_all2b['centerline']=barea_all2b.apply(lambda row: centerline(row['FUNCTIONAL']),axis=1)
barea_all2b.head()
# Out:
#    unique_id  ending_ele  FID  objectid  cnn_x streetname_x from_st_x to_st_x  \
# 0          0          23    0      1652      0
# 1          1          82    1      4773      0
# 2          2          43    3      3319      0
# 3          3          73    4       583      0
# 4          4          33    5      3670      0
#
#   facility_t_x direct_x  ... raised_y contraflow_y greenwave_y biap_y  \
# 0      CLASS I       2W  ...       NO           NO          NO     NO
# 1      CLASS I       2W  ...       NO           NO          NO     NO
# 2      CLASS I       2W  ...       NO           NO          NO     NO
# 3      CLASS I       2W  ...       NO           NO          NO     NO
# 4      CLASS I       2W  ...       NO           NO          NO     NO
#
#    sm_sweeper_y    L_mile                                           geometry  \
# 0            NO  0.267051  LINESTRING (-122.50269 37.70797, -122.50214 37...
# 1            NO  0.155166  LINESTRING (-122.51093 37.78270, -122.51077 37...
# 2            NO  0.143260  LINESTRING (-122.50256 37.71871, -122.50258 37...
# 3            NO  0.056055  LINESTRING (-122.44733 37.77189, -122.44736 37...
# 4            NO  0.039456  LINESTRING (-122.50338 37.71286, -122.50266 37...
#
#        length         slope centerline
# 0  429.780898  4.996694e+08          0
# 1  249.717031  4.805439e+00          0
# 2  230.555997  3.469873e+00          0
# 3   90.213100  0.000000e+00          0
# 4   63.499582  2.834664e+01          0
#
# [5 rows x 129 columns]

# %%
# save this mixed traffic network file
crs = {'init': 'epsg:4326'}
biken = gpd.GeoDataFrame(barea_all2b, crs=crs, geometry = 'geometry')
biken.to_file("bike_network_aug10.json", driver="GeoJSON")
# Out:
# C:\Users\mmmiah\Anaconda3\envs\geo_env\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# # End of the data processing
